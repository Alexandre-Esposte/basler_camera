# %%
import numpy as np
import camera as cam
import watchdog 
import matplotlib.pyplot as plt
import threading
import seriais

# %%
serial1, serial2, serial3, bancada = seriais.NumerosSeriais()

camera = cam.Camera(bancada,exposicao=50000, ganho = 30)
camera.conectar()

a = -11.982797187439544
b = 107.63502457794493
# Out:
# Conexao realizada com sucesso
# Camera configurada com sucesso

# %%
camera.array
# Out:
# array([], dtype=float64)

# %%
camera.movie = False

# %%
camera.Foto()
plt.imshow(camera.array)

# %%
camera.GetTemperatura()
# Out:
# 57.70600000000002

# %%
thread1 = threading.Thread(target = camera.Filme)
thread1.start()

# %%
camera.array
# Out:
# array([[ 6,  9,  9, ..., 31, 27, 32],
#        [ 6,  9,  7, ..., 28, 34, 23],
#        [ 1,  4,  9, ..., 30, 29, 26],
#        ...,
#        [65, 66, 62, ...,  5,  1,  4],
#        [64, 73, 73, ...,  6,  5,  2],
#        [77, 75, 65, ...,  1,  2,  7]], dtype=uint8)
